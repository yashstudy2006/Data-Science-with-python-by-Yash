# %%
name = "Yash"

# %%
name
# Out:
# 'Yash'

# %%
name.upper()
# Out:
# 'YASH'

# %%
name.lower()
# Out:
# 'yash'

# %%
name.endswith("sh")
# Out:
# True

# %%
name.endswith("i")
# Out:
# False

# %%
name.count("a")
# Out:
# 1

# %%
s = "YashwithSonali"
print(len(s)) # output 14
# Out:
# 14

# %%
s[0:4]
# Out:
# 'Yash'

# %%
s[1:-1]
# Out:
# 'ashwithSonal'

# %%
s[1:12]
# Out:
# 'ashwithSona'

# %%
s[-12:-1]
# Out:
# 'shwithSonal'

# %%
s[1:12]
# Out:
# 'ashwithSona'
