# %% [markdown]
# ## Data Collection in Ahmedabad
#
# You hire Sonali and Icsha to help with the project. Sonali lives all the way in Hebbal, and Icsh stays in HSR Layout, so meeting at either place would be a long trip for someone.
# To keep things fair, you decide to set up a meeting at Café in Ahmedabad, a perfect midway point.
#
# ## Three of you sit down and lay out the entire project plan. You break the work into two major parts:
#
# ~ Sonali and Icsha will be in charge of collecting the Instagram follower data.
# ~ You will build the Python Script that will process everything.
#
# By the end of the meeting, everyone is aligned: Sonali and Icsha will focus on accurate data collection, and you’ll focus on making sure the code can handle real-world data seamlessly.
#
# The team is ready, the plan is set, and the project officially kicks off.
#
#
# # Welcome Sam Altman to Ahmedabad
#
# You ask Sam Altman for 2.2 billion USD in funding, and he makes fun of you in public
# He asks you where you live, and finally, after talking to you, gives you a challenging task
# Collect raw Instagram data of all Open AI followers
#
# Answer these questions:
# Who has the maximum posts
# who has the maximum followers
# Who follows the maximum people
#
# How many categories (Digital creators, Non-profit foundation, etc do we have? How many people do we have?
# You have 24 hours!
#
# You then ask for data - he laughs!

# %% [markdown]
# ## Data collection
# You hire Sonali and Icsha who are from Hebbal and HSR layout respectively
# HSR layout and Hebbal are far away so u set up a meeting at Cafe, Ahmedabad!

# %%
with open ("data.txt", encoding='utf-8')as f:
    data = f.read()

# %%
chunks = data.split("\n\n")
chunks = {c for c in chunks if len(c)>3}

# %%
chunks
# Out:
# {'ai_future_lab\n265 posts\n26K followers\n310 following\nAI Future Lab\nArtificial Intelligence\n🤖 AI Tools & News\n🧠 Machine Learning Updates\n📩 Business Contact\naifuturelab.ai',
#  'art_by_sana\n154 posts\n89 followers\n170 following\nSana | Artist\nArt\n🎨 Digital & Traditional Art\n🖌️ Commission Open\n📩 DM to Order\nartbysana.com',
#  'code_with_neha\n134 posts\n15000 followers\n180 following\nNeha | Software Engineer\nEducation\n💻 Python | DSA | AI\n🚀 Helping Beginners Learn Coding\n📩 Workshops & Mentorship\ncodewithneha.dev',
#  'daily_motivation\n1020 posts\n55 followers\n120 following\nDaily Motivation\nEducation\n🔥 Quotes & Success Stories\n🌟 Inspire Every Day\n📩 Partnership Requests\ndailymotivation.in',
#  'fashion_by_isha\n620 posts\n28000 followers\n530 following\nIsha | Fashion Creator\nFashion\n👗 Daily Outfit Inspiration\n✨ Beauty & Lifestyle\n📩 DM for promotions\nfashionbyisha.com',
#  'finance_with_kunal\n205 posts\n17000 followers\n240 following\nKunal | Finance\nFinance\n📈 Stock Market\n💰 Investing Tips\n📩 Business inquiries\nfinancewithkunal.in',
#  'fit_with_aarav\n540 posts\n18000 followers\n420 following\nAarav | Fitness Coach\nHealth & Wellness\n💪 Transform Your Body\nDiet | Workout | Motivation\nOnline coaching available\nfitwithaarav.in',
#  'foodie_krishna\n760 posts\n22000 followers\n610 following\nKrishna | Food Lover\nFood & Drink\nStreet Food Explorer\nReviews & Recipes\nDM for collabs\nzomato.com',
#  'gaming_arena\n390 posts\n42000 followers\n710 following\nGaming Arena\nGaming\n🎮 PC & Mobile Games\n🔥 Live Streams Daily\n📩 Brand Collaborations\ngamingarena.gg',
#  'music_vibes\n870 posts\n39000 followers\n430 following\nMusic Vibes\nMusic\n🎵 Discover New Songs\n🎧 Daily Playlists\n📩 Promotions Open\nmusicvibes.fm',
#  'nature_clicks\n480 posts\n14 followers\n260 following\nNature Clicks\nPhotography\n🌿 Wildlife & Landscapes\n📸 Shot on DSLR\n📩 Prints Available\nnatureclicks.com',
#  'pet_lovers_club\n315 posts\n11000 followers\n350 following\nPet Lovers Club\nAnimals\n🐶 Dogs | Cats | Pets\n❤️ Pet Care Tips\n📩 Feature your pet\npetloversclub.com',
#  'startup_guru\n98 posts\n31000 followers\n540 following\nStartup Guru\nBusiness\n🚀 Startup News & Funding\n💼 Founder Stories\n📩 Feature your startup\nstartupguru.in',
#  'tech_world_raj\n210 posts\n12500 followers\n340 following\nRaj | Tech Reviews\nScience & Technology\nSmartphones | AI | Gadgets Honest reviews & tips DM for collaborations\ntechworldraj.com',
#  'travel_diaries_riya\n185 posts\n9800 followers\n290 following\nRiya | Travel Blogger\nTravel\nExploring Hidden Places\nBudget Travel Tips\nDM for partnerships\nriyatravels.com'}

# %%
def parse_chunk(chunk): 
        chunk = chunk.strip()
        sep_chunk = chunk.split('\n')
        username = sep_chunk[0]
        no_of_posts = int(sep_chunk[1].split(" post")[0].replace(",", ""))
        no_of_followers = float(sep_chunk[2].split(" follower")[0].replace(",", "").replace("K", "").replace("M", ""))
        if("K" in sep_chunk[2]):
            no_of_followers = int(no_of_followers * 1000)
        elif("M" in sep_chunk[2]):
            no_of_followers = int(no_of_followers * 1000000)
        else:
            no_of_followers = int(no_of_followers)
             

    
        no_of_following = float(sep_chunk[3].split(" following")[0].replace(",", "").replace("K", "").replace("M", ""))
        if("K" in sep_chunk[3]):
            no_of_following = int(no_of_following * 1000)
        elif("M" in sep_chunk[3]):
            no_of_following = int(no_of_following * 1000000)
        else:
            no_of_following = int(no_of_following)

            
        name = sep_chunk[4]
        if(len(sep_chunk)> 5):
            type_of_page = sep_chunk[5]
            bio = "\n".join(sep_chunk[6:])
        else:
            type_of_page = "Unknown"
            bio = ""
        
        return {"username": username, "no_of_posts": no_of_posts, "no_of_followers": no_of_followers, "type_of_page": type_of_page,
                "no_of_following": no_of_following, "name": name, "type_of_page": type_of_page, "bio": bio}

# %%
all_chunks = [] 
for chunk in chunks:  
    parsed_chunk = parse_chunk(chunk)
    all_chunks.append(parsed_chunk)
print(all_chunks)
# Out:
# [{'username': 'code_with_neha', 'no_of_posts': 134, 'no_of_followers': 15000, 'type_of_page': 'Education', 'no_of_following': 180, 'name': 'Neha | Software Engineer', 'bio': '💻 Python | DSA | AI\n🚀 Helping Beginners Learn Coding\n📩 Workshops & Mentorship\ncodewithneha.dev'}, {'username': 'foodie_krishna', 'no_of_posts': 760, 'no_of_followers': 22000, 'type_of_page': 'Food & Drink', 'no_of_following': 610, 'name': 'Krishna | Food Lover', 'bio': 'Street Food Explorer\nReviews & Recipes\nDM for collabs\nzomato.com'}, {'username': 'art_by_sana', 'no_of_posts': 154, 'no_of_followers': 89, 'type_of_page': 'Art', 'no_of_following': 170, 'name': 'Sana | Artist', 'bio': '🎨 Digital & Traditional Art\n🖌️ Commission Open\n📩 DM to Order\nartbysana.com'}, {'username': 'daily_motivation', 'no_of_posts': 1020, 'no_of_followers': 55, 'type_of_page': 'Education', 'no_of_following': 120, 'name': 'Daily Motivation', 'bio': '🔥 Quotes & Success Stories\n🌟 Inspire Every Day\n📩 Partnership Requests\ndailymotivation.in'}, {'username': 'ai_future_lab', 'no_of_posts': 265, 'no_of_followers': 26000, 'type_of_page': 'Artificial Intelligence', 'no_of_following': 310, 'name': 'AI Future Lab', 'bio': '🤖 AI Tools & News\n🧠 Machine Learning Updates\n📩 Business Contact\naifuturelab.ai'}, {'username': 'pet_lovers_club', 'no_of_posts': 315, 'no_of_followers': 11000, 'type_of_page': 'Animals', 'no_of_following': 350, 'name': 'Pet Lovers Club', 'bio': '🐶 Dogs | Cats | Pets\n❤️ Pet Care Tips\n📩 Feature your pet\npetloversclub.com'}, {'username': 'nature_clicks', 'no_of_posts': 480, 'no_of_followers': 14, 'type_of_page': 'Photography', 'no_of_following': 260, 'name': 'Nature Clicks', 'bio': '🌿 Wildlife & Landscapes\n📸 Shot on DSLR\n📩 Prints Available\nnatureclicks.com'}, {'username': 'finance_with_kunal', 'no_of_posts': 205, 'no_of_followers': 17000, 'type_of_page': 'Finance', 'no_of_following': 240, 'name': 'Kunal | Finance', 'bio': '📈 Stock Market\n💰 Investing Tips\n📩 Business inquiries\nfinancewithkunal.in'}, {'username': 'fit_with_aarav', 'no_of_posts': 540, 'no_of_followers': 18000, 'type_of_page': 'Health & Wellness', 'no_of_following': 420, 'name': 'Aarav | Fitness Coach', 'bio': '💪 Transform Your Body\nDiet | Workout | Motivation\nOnline coaching available\nfitwithaarav.in'}, {'username': 'startup_guru', 'no_of_posts': 98, 'no_of_followers': 31000, 'type_of_page': 'Business', 'no_of_following': 540, 'name': 'Startup Guru', 'bio': '🚀 Startup News & Funding\n💼 Founder Stories\n📩 Feature your startup\nstartupguru.in'}, {'username': 'fashion_by_isha', 'no_of_posts': 620, 'no_of_followers': 28000, 'type_of_page': 'Fashion', 'no_of_following': 530, 'name': 'Isha | Fashion Creator', 'bio': '👗 Daily Outfit Inspiration\n✨ Beauty & Lifestyle\n📩 DM for promotions\nfashionbyisha.com'}, {'username': 'gaming_arena', 'no_of_posts': 390, 'no_of_followers': 42000, 'type_of_page': 'Gaming', 'no_of_following': 710, 'name': 'Gaming Arena', 'bio': '🎮 PC & Mobile Games\n🔥 Live Streams Daily\n📩 Brand Collaborations\ngamingarena.gg'}, {'username': 'tech_world_raj', 'no_of_posts': 210, 'no_of_followers': 12500, 'type_of_page': 'Science & Technology', 'no_of_following': 340, 'name': 'Raj | Tech Reviews', 'bio': 'Smartphones | AI | Gadgets Honest reviews & tips DM for collaborations\ntechworldraj.com'}, {'username': 'music_vibes', 'no_of_posts': 870, 'no_of_followers': 39000, 'type_of_page': 'Music', 'no_of_following': 430, 'name': 'Music Vibes', 'bio': '🎵 Discover New Songs\n🎧 Daily Playlists\n📩 Promotions Open\nmusicvibes.fm'}, {'username': 'travel_diaries_riya', 'no_of_posts': 185, 'no_of_followers': 9800, 'type_of_page': 'Travel', 'no_of_following': 290, 'name': 'Riya | Travel Blogger', 'bio': 'Exploring Hidden Places\nBudget Travel Tips\nDM for partnerships\nriyatravels.com'}]

# %%
import json
s = json.dumps(all_chunks, indent=4) 
with open("data.json", "w")as f:
    f.write(s)

# %% [markdown]
# # Who has maximum no. of post
# Lets write code to find out!

# %%
max = 0
for chunk in all_chunks:
    if(max<chunk['no_of_posts']):
        max = chunk['no_of_posts']
        chunk_with_max_post = chunk
print(chunk_with_max_post['username'])
# Out:
# daily_motivation

# %% [markdown]
# # Who has maximum no. of followers
# Lets write code to find out maximum follower!

# %%
max = 0
for chunk in all_chunks:
    if(max<chunk['no_of_followers']):
        max = chunk['no_of_followers']
        chunk_with_max_followers = chunk
print(chunk_with_max_followers['username'])
# Out:
# gaming_arena

# %% [markdown]
# # Who follows maximum people!
# Lets write code to find out maximum following people!

# %%
max = 0
for chunk in all_chunks:
    if(max<chunk['no_of_following']):
        max = chunk['no_of_following']
        chunk_with_max_following = chunk
print(chunk_with_max_following['username'])
# Out:
# gaming_arena

# %% [markdown]
# # How many catergories?
# Lets write a code to find out number of categories

# %%
categories = set()
for chunk in all_chunks:
    categories.add(chunk['type_of_page'])
print(categories, f"There are {len(categories)} categorcategories")
# Out:
# {'Gaming', 'Finance', 'Food & Drink', 'Photography', 'Health & Wellness', 'Animals', 'Science & Technology', 'Artificial Intelligence', 'Art', 'Education', 'Fashion', 'Business', 'Music', 'Travel'} There are 14 categorcategories
